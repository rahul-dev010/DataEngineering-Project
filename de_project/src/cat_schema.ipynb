# %%
# %sql
create catalog if not exists de_dev;

create schema if not exists de_dev.bronze;
create schema if not exists de_dev.silver;
create schema if not exists de_dev.gold;

create volume if not exists de_dev.bronze.raw;

create catalog if not exists de_uat;
create schema if not exists de_uat.bronze;
create schema if not exists de_uat.silver;
create schema if not exists de_uat.gold;

create volume if not exists de_uat.bronze.raw;

create catalog if not exists de_prod;
create schema if not exists de_prod.bronze;
create schema if not exists de_prod.silver;
create schema if not exists de_prod.gold;

create volume if not exists de_prod.bronze.raw;
