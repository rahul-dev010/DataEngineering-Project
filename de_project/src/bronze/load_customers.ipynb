# %%
# %run "/Workspace/Users/rahulpatel@cyntexa.com/DataEngineering-Project/de_project/src/includes"

# %%
dbutils.widgets.text("catalog", "de_dev")
# print(dbutils.widgets.get("catalog"))

# %%
# %sql

COPY INTO IDENTIFIER('${catalog}.bronze.customers')
FROM (
  SELECT
    customer_id, name, email, city, state, signup_date, phone,
    current_timestamp() AS ingestion_timestamp,
    _metadata.file_name AS file_name,
    _metadata.file_path AS file_path

  FROM '/Volumes/${catalog}/bronze/raw/customers'
)
FILEFORMAT = CSV
FORMAT_OPTIONS ('header' = 'true', 'inferSchema' = 'true')
COPY_OPTIONS ('mergeSchema' = 'true');

# %%
# df = spark.read.option("header", "true").option("inferSchema", "true").csv("/Volumes/de_dev/bronze/raw/customers")
# df.printSchema()

# %%
# %sql
-- DESCRIBE TABLE de_dev.bronze.customers
